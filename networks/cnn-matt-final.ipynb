# %%
import tensorflow.keras as keras
from tensorflow.keras.preprocessing import image
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Depending on your runtime environment you may need the following lines\

physical_devices = tf.config.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
# The tensorflow.keras.preprocessing library contains classes that
# simplify basic data collection and processing.
# https://keras.io/api/preprocessing/image/#imagedatagenerator-class
datagen = image.ImageDataGenerator(
    validation_split=0.2,
    dtype="float32"
)

dir_path = "../../leabra"
img_size = (200, 200)

# imort training data
train = datagen.flow_from_directory(
    dir_path,
    target_size=img_size,
    color_mode="rgb",
    class_mode="categorical",
    batch_size=2000,
    shuffle=True,
    seed=50,
    subset="training"
)

# import testing data
test = datagen.flow_from_directory(
    dir_path,
    target_size=img_size,
    color_mode="rgb",
    class_mode="categorical",
    batch_size=2000,
    shuffle=True,
    seed=50,
    subset="validation"
)

# Converts tf.data.Dataset object to a numpy array
x_train, y_train = train.next()
x_test, y_test = test.next()
# Out:
# Found 992 images belonging to 2 classes.
# Found 247 images belonging to 2 classes.

# %%
print(x_train.dtype)
print(x_train.shape)
# Out:
# float32
# (992, 200, 200, 3)

# %%
input_shape = x_train[0].shape
output_shape = y_train.shape[1]
print(input_shape)
print(output_shape)
# Out:
# (200, 200, 3)
# 2

# %%
# specifying the overall grid size
plt.figure(figsize=(20, 20))

for i in range(7):
    plt.subplot(7, 7, i+1)
    plt.title(str(y_train[i]))
    plt.imshow(x_train[i].astype('uint8'))
plt.show()

# %%
# Set the parameters for a performance export
conv_size = 96
momentum = 0.4

# %%
model = keras.Sequential()

model.add(layers.Conv2D(conv_size, (5, 5),
                        activation='relu',
                        input_shape=input_shape))
model.add(layers.Conv2D(128, (4, 4), activation='relu'))

model.add(layers.BatchNormalization(momentum=momentum))
model.add(layers.MaxPooling2D(pool_size=(6, 6)))
model.add(layers.Dropout(0.5))
model.add(layers.Flatten())
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(output_shape, activation='softmax'))

model.compile(loss=keras.losses.CategoricalCrossentropy(),
              optimizer=keras.optimizers.Adam(),
              metrics=[keras.metrics.CategoricalAccuracy()])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 196, 196, 96)      7296
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 193, 193, 128)     196736
# _________________________________________________________________
# batch_normalization (BatchNo (None, 193, 193, 128)     512
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 32, 32, 128)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 32, 32, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 131072)            0
# _________________________________________________________________
# dense (Dense)                (None, 128)               16777344
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 16,982,146
# Trainable params: 16,981,890
# Non-trainable params: 256
# _________________________________________________________________

# %%
batch_size = 32
epochs = 30
history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
# Out:
# Epoch 1/30
# 31/31 [==============================] - 12s 181ms/step - loss: 29.6264 - categorical_accuracy: 0.5062 - val_loss: 41.8815 - val_categorical_accuracy: 0.5425
# Epoch 2/30
# 31/31 [==============================] - 5s 161ms/step - loss: 6.7113 - categorical_accuracy: 0.6020 - val_loss: 4.2762 - val_categorical_accuracy: 0.5830
# Epoch 3/30
# 31/31 [==============================] - 5s 154ms/step - loss: 1.2612 - categorical_accuracy: 0.6052 - val_loss: 1.8775 - val_categorical_accuracy: 0.6235
# Epoch 4/30
# 31/31 [==============================] - 5s 154ms/step - loss: 0.7382 - categorical_accuracy: 0.7004 - val_loss: 1.3467 - val_categorical_accuracy: 0.6802
# Epoch 5/30
# 31/31 [==============================] - 5s 155ms/step - loss: 0.6239 - categorical_accuracy: 0.7181 - val_loss: 1.4084 - val_categorical_accuracy: 0.6964
# Epoch 6/30
# 31/31 [==============================] - 5s 155ms/step - loss: 0.6008 - categorical_accuracy: 0.7213 - val_loss: 0.8587 - val_categorical_accuracy: 0.8057
# Epoch 7/30
# 31/31 [==============================] - 5s 157ms/step - loss: 0.5083 - categorical_accuracy: 0.8120 - val_loss: 0.8199 - val_categorical_accuracy: 0.7652
# Epoch 8/30
# 31/31 [==============================] - 5s 153ms/step - loss: 0.4067 - categorical_accuracy: 0.8255 - val_loss: 0.5527 - val_categorical_accuracy: 0.8381
# Epoch 9/30
# 31/31 [==============================] - 5s 157ms/step - loss: 0.2824 - categorical_accuracy: 0.8732 - val_loss: 0.6868 - val_categorical_accuracy: 0.8259
# Epoch 10/30
# 31/31 [==============================] - 5s 156ms/step - loss: 0.2643 - categorical_accuracy: 0.8748 - val_loss: 0.6161 - val_categorical_accuracy: 0.7611
# Epoch 11/30
# 31/31 [==============================] - 5s 156ms/step - loss: 0.2811 - categorical_accuracy: 0.8860 - val_loss: 0.5422 - val_categorical_accuracy: 0.8138
# Epoch 12/30
# 31/31 [==============================] - 5s 156ms/step - loss: 0.2142 - categorical_accuracy: 0.9068 - val_loss: 0.7068 - val_categorical_accuracy: 0.8259
# Epoch 13/30
# 31/31 [==============================] - 5s 156ms/step - loss: 0.1877 - categorical_accuracy: 0.9221 - val_loss: 0.6633 - val_categorical_accuracy: 0.8462
# Epoch 14/30
# 31/31 [==============================] - 5s 156ms/step - loss: 0.3122 - categorical_accuracy: 0.9060 - val_loss: 0.6792 - val_categorical_accuracy: 0.8421
# Epoch 15/30
# 31/31 [==============================] - 5s 157ms/step - loss: 0.2168 - categorical_accuracy: 0.9028 - val_loss: 0.6594 - val_categorical_accuracy: 0.8178
# Epoch 16/30
# 31/31 [==============================] - 5s 158ms/step - loss: 0.1830 - categorical_accuracy: 0.9154 - val_loss: 0.8186 - val_categorical_accuracy: 0.8178
# Epoch 17/30
# 31/31 [==============================] - 5s 157ms/step - loss: 0.1427 - categorical_accuracy: 0.9328 - val_loss: 0.6590 - val_categorical_accuracy: 0.8462
# Epoch 18/30
# 31/31 [==============================] - 5s 159ms/step - loss: 0.1258 - categorical_accuracy: 0.9435 - val_loss: 0.6070 - val_categorical_accuracy: 0.8219
# Epoch 19/30
# 31/31 [==============================] - 5s 157ms/step - loss: 0.1616 - categorical_accuracy: 0.9350 - val_loss: 0.7124 - val_categorical_accuracy: 0.8462
# Epoch 20/30
# 31/31 [==============================] - 5s 156ms/step - loss: 0.1071 - categorical_accuracy: 0.9541 - val_loss: 0.8272 - val_categorical_accuracy: 0.8421
# Epoch 21/30
# 31/31 [==============================] - 5s 156ms/step - loss: 0.1376 - categorical_accuracy: 0.9570 - val_loss: 0.7722 - val_categorical_accuracy: 0.8340
# Epoch 22/30
# 31/31 [==============================] - 5s 153ms/step - loss: 0.1043 - categorical_accuracy: 0.9478 - val_loss: 0.7543 - val_categorical_accuracy: 0.8340
# Epoch 23/30
# 31/31 [==============================] - 5s 156ms/step - loss: 0.1581 - categorical_accuracy: 0.9376 - val_loss: 0.6912 - val_categorical_accuracy: 0.8138
# Epoch 24/30
# 31/31 [==============================] - 5s 156ms/step - loss: 0.1194 - categorical_accuracy: 0.9514 - val_loss: 0.6656 - val_categorical_accuracy: 0.8259
# Epoch 25/30
# 31/31 [==============================] - 5s 155ms/step - loss: 0.1518 - categorical_accuracy: 0.9540 - val_loss: 0.7019 - val_categorical_accuracy: 0.8623
# Epoch 26/30
# 31/31 [==============================] - 5s 155ms/step - loss: 0.0969 - categorical_accuracy: 0.9559 - val_loss: 0.6160 - val_categorical_accuracy: 0.8502
# Epoch 27/30
# 31/31 [==============================] - 5s 164ms/step - loss: 0.1170 - categorical_accuracy: 0.9414 - val_loss: 0.6832 - val_categorical_accuracy: 0.8785
# Epoch 28/30
# 31/31 [==============================] - 5s 159ms/step - loss: 0.0992 - categorical_accuracy: 0.9555 - val_loss: 0.5551 - val_categorical_accuracy: 0.8664
# Epoch 29/30
# 31/31 [==============================] - 5s 162ms/step - loss: 0.0942 - categorical_accuracy: 0.9604 - val_loss: 0.6609 - val_categorical_accuracy: 0.8664
# Epoch 30/30
# 31/31 [==============================] - 5s 156ms/step - loss: 0.0708 - categorical_accuracy: 0.9727 - val_loss: 0.7384 - val_categorical_accuracy: 0.8543

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print("Test loss:", score[0])
print("Test accuracy:", score[1])

plt.figure(1)

# summarize history for accuracy
plt.subplot(211)
plt.plot(history.history['categorical_accuracy'])
plt.plot(history.history['val_categorical_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')

# summarize history for loss
plt.subplot(212)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.tight_layout()

# save format convolution layer size, batch
# normalization momentum, batch size, epochs
save_to = './performance-logs/%s-%s-%s-%s.jpeg' % (str(conv_size), str(momentum), str(batch_size), str(epochs))
plt.savefig(save_to)

plt.show()
# Out:
# Test loss: 0.738440215587616
# Test accuracy: 0.8542510271072388

# %% [markdown]
# ### Verify the predictions being made
# ---

# %%
def decoder(one_pred):
    if one_pred[0] > one_pred[1]:
        return np.float32([1, 0])
    else:
        return [0, 1]


squat_preds = model.predict(x_test)
decoded = np.apply_along_axis(decoder, 1, squat_preds)

incorrect_squats = []
incorrect_non_squats = []

for i in range(len(y_test)):
    if (np.array_equal(decoded[i], y_test[i])) is False:
        if y_test[i][0] == 1:
            incorrect_non_squats.append(i)
        else:
            incorrect_squats.append(i)

print('\nNumber of incorrectly identified squats: ', len(incorrect_squats))
for i in incorrect_squats:
    plt.imshow(image.array_to_img(x_test[i, :, :, :]))
    plt.title(str(squat_preds[i]))
    plt.show()

print('Number of incorrectly identified non-squats: ', len(incorrect_non_squats))
for i in incorrect_non_squats:
    plt.imshow(image.array_to_img(x_test[i, :, :, :]))
    plt.title(str(squat_preds[i]))
    plt.show()
# Out:
# Number of incorrectly identified non-squats:  16
# Number of incorrectly identified squats:  20
